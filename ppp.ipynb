# %% [markdown]
# <a href="https://colab.research.google.com/github/Nutsudapenpong/DPDM/blob/master/ppp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
base_path = '/content/drive/My Drive/TEST'

# %%
os.listdir(base_path)
# Out:
# ['Fertility_new.xlsx', 'countries_of_the_world.xlsx']

# %%
Countries_name = os.path.join(base_path, 'countries_of_the_world.xlsx')
Fertility_name = os.path.join(base_path, 'Fertility_new.xlsx')

# %%
Countries_name2 = pd.read_excel(Countries_name)

# %%
Countries_name2
# Out:
#                  Country  ... GDP per capita
# 0            Afghanistan  ...         2182.0
# 1                Algeria  ...        16091.0
# 2                 Angola  ...         6763.0
# 3    Antigua and Barbuda  ...        30593.0
# 4              Argentina  ...        19971.0
# ..                   ...  ...            ...
# 212           West Bank   ...            NaN
# 213      Western Sahara   ...            NaN
# 214                Yemen  ...            NaN
# 215               Zambia  ...            NaN
# 216             Zimbabwe  ...            NaN
#
# [217 rows x 20 columns]

# %%
Fertility_name2 = pd.read_excel(Fertility_name)

# %%
Fertility_name2
# Out:
#                  Country  Fertility  ...  Suicide rate  Urbanization rate
# 0            Afghanistan        4.5  ...           6.4               26.0
# 1                Algeria        3.0  ...           3.3               73.7
# 2                 Angola        5.5  ...           8.9               66.8
# 3    Antigua and Barbuda        2.0  ...           0.5               24.4
# 4              Argentina        2.3  ...           9.1               92.1
# ..                   ...        ...  ...           ...                ...
# 152            Venezuela        2.3  ...           3.8               88.3
# 153              Vietnam        2.0  ...           7.0               37.3
# 154                Yemen        3.8  ...           9.8               36.6
# 155               Zambia        4.6  ...          11.3               44.6
# 156             Zimbabwe        3.6  ...          19.1               32.2
#
# [157 rows x 10 columns]

# %%
New_table = Countries_name2.merge(Fertility_name2, on='Country')

# %%
New_table
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...              26.0
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
# 156             Zimbabwe  ...              32.2
#
# [157 rows x 29 columns]

# %%
New_table.head()
# Out:
#                Country  ... Urbanization rate
# 0          Afghanistan  ...              26.0
# 1              Algeria  ...              73.7
# 2               Angola  ...              66.8
# 3  Antigua and Barbuda  ...              24.4
# 4            Argentina  ...              92.1
#
# [5 rows x 29 columns]

# %%
New_table.tail()
# Out:
#        Country  ... Urbanization rate
# 152  Venezuela  ...              88.3
# 153    Vietnam  ...              37.3
# 154      Yemen  ...              36.6
# 155     Zambia  ...              44.6
# 156   Zimbabwe  ...              32.2
#
# [5 rows x 29 columns]

# %%
New_table.shape
# Out:
# (157, 29)

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(New_table['Country'], New_table['Life expectancy'])

# %%
plt.scatter(New_table['Country'], New_table['Suicide rate'])

# %%
New_table.describe()
# Out:
#          Population  Area (sq. mi.)  ...  Suicide rate  Urbanization rate
# count  1.570000e+02    1.570000e+02  ...    157.000000         157.000000
# mean   3.971542e+07    8.326234e+05  ...      9.777070          59.042675
# std    1.402978e+08    2.103617e+06  ...      5.510908          22.367459
# min    5.636100e+04    3.160000e+02  ...      0.400000          13.300000
# 25%    3.177388e+06    5.110000e+04  ...      5.900000          42.200000
# 50%    8.989046e+06    2.076000e+05  ...      9.100000          58.400000
# 75%    2.701973e+07    6.376570e+05  ...     12.900000          78.100000
# max    1.313974e+09    1.707520e+07  ...     30.200000         100.000000
#
# [8 rows x 26 columns]

# %%
New_table.isnull()
# Out:
#      Country  Region  Population  ...  Sex-ratio  Suicide rate  Urbanization rate
# 0      False   False       False  ...      False         False              False
# 1      False   False       False  ...      False         False              False
# 2      False   False       False  ...      False         False              False
# 3      False   False       False  ...      False         False              False
# 4      False   False       False  ...      False         False              False
# ..       ...     ...         ...  ...        ...           ...                ...
# 152    False   False       False  ...      False         False              False
# 153    False   False       False  ...      False         False              False
# 154    False   False       False  ...      False         False              False
# 155    False   False       False  ...      False         False              False
# ...

# %%
New_table.isnull().any()
# Out:
# Country                               False
# Region                                False
# Population                            False
# Area (sq. mi.)                        False
# Pop. Density (per sq. mi.)            False
# Coastline (coast/area ratio)          False
# Net migration                         False
# Infant mortality (per 1000 births)    False
# Literacy (%)                           True
# Phones (per 1000)                      True
# Arable (%)                            False
# Crops (%)                             False
# Other (%)                             False
# Climate                                True
# Birthrate                              True
# Deathrate                              True
# Agriculture                            True
# Industry                               True
# Service                                True
# GDP per capita_x                       True
# Fertility                             False
# ...

# %%
New_table.isnull().any().any()
# Out:
# True

# %%
New_table_nm = New_table.dropna()

# %%
New_table_nm
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...              26.0
# 1                Algeria  ...              73.7
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# 5                Armenia  ...              63.3
# ..                   ...  ...               ...
# 112     Papua New Guinea  ...              13.3
# 113             Paraguay  ...              62.2
# 114                 Peru  ...              78.3
# 115          Philippines  ...              47.4
# 116               Poland  ...              60.0
#
# [100 rows x 29 columns]

# %%
New_table_nm.isnull().any().any()
# Out:
# False

# %%
print(New_table.shape) 
print(New_table_nm.shape)
# Out:
# (157, 29)
# (100, 29)

# %%
New_table.shape[0] - New_table_nm.shape[0]
# Out:
# 57

# %%
((New_table.shape[0] - New_table_nm.shape[0] )*100)/New_table.shape[0]
# Out:
# 36.30573248407644

# %%
New2_table = New_table[['Country', 'Region', 'Life expectancy', 'Suicide rate']]
New2_table
# Out:
#                  Country  ... Suicide rate
# 0            Afghanistan  ...          6.4
# 1                Algeria  ...          3.3
# 2                 Angola  ...          8.9
# 3    Antigua and Barbuda  ...          0.5
# 4              Argentina  ...          9.1
# ..                   ...  ...          ...
# 152            Venezuela  ...          3.8
# 153              Vietnam  ...          7.0
# 154                Yemen  ...          9.8
# 155               Zambia  ...         11.3
# 156             Zimbabwe  ...         19.1
#
# [157 rows x 4 columns]

# %%
New3_table = New2_table[New2_table['Region'] == 'ASIA (EX. NEAR EAST)         ']
print(New3_table)
New3_table.shape
# Out:
#          Country                         Region  Life expectancy  Suicide rate
# 0    Afghanistan  ASIA (EX. NEAR EAST)                      64.5           6.4
# 10    Bangladesh  ASIA (EX. NEAR EAST)                      72.3           6.1
# 16        Bhutan  ASIA (EX. NEAR EAST)                      71.5          11.6
# 24      Cambodia  ASIA (EX. NEAR EAST)                      69.6           5.9
# 31         China  ASIA (EX. NEAR EAST)                      76.7           8.0
# 41    East Timor  ASIA (EX. NEAR EAST)                      69.3           6.4
# 64         India  ASIA (EX. NEAR EAST)                      69.4          16.5
# 65     Indonesia  ASIA (EX. NEAR EAST)                      71.5           3.7
# 66          Iran  ASIA (EX. NEAR EAST)                      76.5           4.0
# 72         Japan  ASIA (EX. NEAR EAST)                      84.5          14.3
# 79          Laos  ASIA (EX. NEAR EAST)                      67.6           9.3
# ...

# %%
New2_table
# Out:
#                  Country  ... Suicide rate
# 0            Afghanistan  ...          6.4
# 1                Algeria  ...          3.3
# 2                 Angola  ...          8.9
# 3    Antigua and Barbuda  ...          0.5
# 4              Argentina  ...          9.1
# ..                   ...  ...          ...
# 152            Venezuela  ...          3.8
# 153              Vietnam  ...          7.0
# 154                Yemen  ...          9.8
# 155               Zambia  ...         11.3
# 156             Zimbabwe  ...         19.1
#
# [157 rows x 4 columns]

# %%
New2_table[New2_table['Region'] == 'NORTHERN AFRICA']
# Out:
# Empty DataFrame
# Columns: [Country, Region, Life expectancy, Suicide rate]
# Index: []

# %%
b = New2_table[New2_table['Country'] == 'Algeria']
b
# Out:
#    Country                               Region  Life expectancy  Suicide rate
# 1  Algeria  NORTHERN AFRICA                                 76.7           3.3

# %%
ret = plt.boxplot(New_table['Life expectancy'], showmeans=True, whis=0.8, vert=False)

# %%
ret
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fa476a79c18>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa476a84668>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa476a0b470>],
#  'means': [<matplotlib.lines.Line2D at 0x7fa476a0b128>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa476a84d68>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fa476a79f28>,
#   <matplotlib.lines.Line2D at 0x7fa476a842e8>]}

# %%
ret['fliers']

# %%
ret['fliers'][0].get_xdata()
# Out:
# array([58.9, 52.8, 54. , 58. , 53.7, 58.9, 54.3, 54.3, 56.7])

# %%
ret['whiskers'][0].get_xdata()
# Out:
# array([67.1, 60.2])

# %%
ret['whiskers'][1].get_xdata()
# Out:
# array([77.2, 84.5])

# %%
ret['boxes'][0].get_xdata()
# Out:
# array([67.1, 67.1, 77.2, 77.2, 67.1])

# %%
ret2 = plt.boxplot(New_table['Suicide rate'], showmeans=True, whis=0.8, vert=False)

# %%
ret2
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fa4769e1240>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa4769e1c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa4769e9a58>],
#  'means': [<matplotlib.lines.Line2D at 0x7fa4769e9710>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa4769e9390>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fa4769e1550>,
#   <matplotlib.lines.Line2D at 0x7fa4769e18d0>]}

# %%
ret2['fliers']

# %%
ret2['fliers'][0].get_xdata()
# Out:
# array([21.4, 19.5, 30.2, 22.8, 28.9, 25.7, 26.5, 23.2, 20. , 19.1])

# %%
ret2['whiskers'][0].get_xdata()
# Out:
# array([5.9, 0.4])

# %%
ret2['whiskers'][1].get_xdata()
# Out:
# array([12.9, 18.5])

# %%
ret2['boxes'][0].get_xdata()
# Out:
# array([ 5.9,  5.9, 12.9, 12.9,  5.9])

# %%
New_table_nm_no_missing = New_table_nm[New_table_nm['Life expectancy']>=ret['whiskers'][0].get_xdata()[1]]
New_table_nm_no_missing = New_table_nm_no_missing[(New_table_nm_no_missing['Life expectancy']<=ret['whiskers'][1].get_xdata()[1])]

# %%
New_table_nm_no_missing2 = New_table_nm[New_table_nm['Suicide rate']>=ret2['whiskers'][0].get_xdata()[1]]
New_table_nm_no_missing2 = New_table_nm_no_missing2[(New_table_nm_no_missing2['Suicide rate']<=ret2['whiskers'][1].get_xdata()[1])]

# %%
New_table_nm_no_missing = New_table_nm_no_missing.sort_values('Life expectancy')
New_table_nm_no_missing
# Out:
#          Country  ... Urbanization rate
# 99    Mozambique  ...              37.1
# 57     Guatemala  ...              51.8
# 23       Burundi  ...              13.7
# 22  Burkina Faso  ...              30.6
# 15         Benin  ...              48.4
# ..           ...  ...               ...
# 49        France  ...              81.0
# 69        Israel  ...              92.6
# 63       Iceland  ...              93.9
# 6      Australia  ...              86.2
# 72         Japan  ...              91.8
#
# [93 rows x 29 columns]

# %%
New_s = New_table_nm_no_missing[New_table_nm_no_missing['Life expectancy']< 65]
New_s['Life expectancy']
# Out:
# 99     60.2
# 57     61.2
# 23     61.2
# 22     61.2
# 15     61.5
# 105    62.0
# 75     63.3
# 100    63.4
# 83     63.7
# 60     63.7
# 88     63.8
# 53     63.8
# 33     64.1
# 112    64.3
# 0      64.5
# 93     64.7
# Name: Life expectancy, dtype: float64

# %%
New_ss = New_table_nm_no_missing.replace([New_s['Life expectancy']],'0')
New_ss
# Out:
#          Country  ... Urbanization rate
# 99    Mozambique  ...              37.1
# 57     Guatemala  ...              51.8
# 23       Burundi  ...              13.7
# 22  Burkina Faso  ...              30.6
# 15         Benin  ...              48.4
# ..           ...  ...               ...
# 49        France  ...                81
# 69        Israel  ...              92.6
# 63       Iceland  ...              93.9
# 6      Australia  ...              86.2
# 72         Japan  ...              91.8
#
# [93 rows x 29 columns]

# %%
New_h = New_table_nm_no_missing[New_table_nm_no_missing['Life expectancy'] > 75]
New_h['Life expectancy']
# Out:
# 61     75.1
# 80     75.2
# 77     75.4
# 20     75.7
# 89     76.1
# 66     76.5
# 4      76.5
# 114    76.5
# 31     76.7
# 62     76.7
# 1      76.7
# 42     76.8
# 3      76.9
# 32     77.1
# 9      77.2
# 109    77.6
# 111    78.3
# 116    78.5
# 46     78.6
# 36     78.6
# 11     79.1
# 37     79.2
# 30     80.0
# 34     80.1
# 38     80.8
# 52     81.2
# 7      81.4
# 13     81.5
# 54     82.1
# 103    82.1
# 102    82.1
# 68     82.1
# 108    82.5
# 49     82.5
# 69     82.8
# 63     82.9
# 6      83.3
# 72     84.5
# Name: Life expectancy, dtype: float64

# %%
New_hh = New_table_nm_no_missing.replace([New_h['Life expectancy']],'2')
New_hh
# Out:
#          Country  ... Urbanization rate
# 99    Mozambique  ...              37.1
# 57     Guatemala  ...              51.8
# 23       Burundi  ...              13.7
# 22  Burkina Faso  ...              30.6
# 15         Benin  ...              48.4
# ..           ...  ...               ...
# 49        France  ...                81
# 69        Israel  ...              92.6
# 63       Iceland  ...              93.9
# 6      Australia  ...              86.2
# 72         Japan  ...              91.8
#
# [93 rows x 29 columns]

# %%
New_m = New_table_nm_no_missing[New_table_nm_no_missing['Life expectancy'] >= 65]
New_m2 = New_m[New_m['Life expectancy'] <= 75]
New_m2['Life expectancy']
# Out:
# 45     65.9
# 47     66.2
# 50     66.2
# 39     66.6
# 87     66.7
# 110    67.1
# 48     67.3
# 79     67.6
# 19     69.3
# 64     69.4
# 24     69.6
# 97     69.7
# 59     69.8
# 67     70.5
# 115    71.1
# 17     71.2
# 78     71.3
# 65     71.5
# 16     71.5
# 43     71.8
# 10     72.3
# 56     72.4
# 27     72.8
# 8      72.9
# 44     73.1
# 74     73.2
# 51     73.6
# 40     73.9
# 92     73.9
# 113    74.1
# 104    74.3
# 73     74.4
# 71     74.4
# 14     74.5
# 12     74.6
# 94     74.9
# 21     74.9
# 5      74.9
# 95     75.0
# Name: Life expectancy, dtype: float64

# %%
New_mm = New_table_nm_no_missing.replace([New_m2['Life expectancy']],'1')
New_mm
# Out:
#          Country  ... Urbanization rate
# 99    Mozambique  ...              37.1
# 57     Guatemala  ...              51.8
# 23       Burundi  ...              13.7
# 22  Burkina Faso  ...              30.6
# 15         Benin  ...              48.4
# ..           ...  ...               ...
# 49        France  ...                81
# 69        Israel  ...              92.6
# 63       Iceland  ...              93.9
# 6      Australia  ...              86.2
# 72         Japan  ...              91.8
#
# [93 rows x 29 columns]

# %%
New_world = New_ss.replace([New_h['Life expectancy']],'high')
New_world
# Out:
#          Country  ... Urbanization rate
# 99    Mozambique  ...              37.1
# 57     Guatemala  ...              51.8
# 23       Burundi  ...              13.7
# 22  Burkina Faso  ...              30.6
# 15         Benin  ...              48.4
# ..           ...  ...               ...
# 49        France  ...                81
# 69        Israel  ...              92.6
# 63       Iceland  ...              93.9
# 6      Australia  ...              86.2
# 72         Japan  ...              91.8
#
# [93 rows x 29 columns]

# %%
New_world2 = New_world.replace([New_m['Life expectancy']],'middle')
New_world2
# Out:
#          Country  ... Urbanization rate
# 99    Mozambique  ...              37.1
# 57     Guatemala  ...              51.8
# 23       Burundi  ...              13.7
# 22  Burkina Faso  ...              30.6
# 15         Benin  ...              48.4
# ..           ...  ...               ...
# 49        France  ...                81
# 69        Israel  ...              92.6
# 63       Iceland  ...              93.9
# 6      Australia  ...              86.2
# 72         Japan  ...              91.8
#
# [93 rows x 29 columns]

# %%
New_world2[49:50]
# Out:
#    Country                   Region  ...  Suicide rate  Urbanization rate
# 14  Belize  LATIN AMER. & CARIB      ...           5.9                 46
#
# [1 rows x 29 columns]

# %%
x = New_world2[['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)', 'Net migration', 'Infant mortality (per 1000 births)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service',	'GDP per capita_x',	'Fertility', 'GDP per capita_y', 'Meat consumption',	'Median age',	'Population growth',	'Sex-ratio','Urbanization rate']]
x
# Out:
#     Population  Area (sq. mi.)  ... Sex-ratio  Urbanization rate
# 99    19686505          801590  ...      0.97               37.1
# 57    12293545          108890  ...      0.99               51.8
# 23     8090068           27830  ...      0.99               13.7
# 22    13902972          274200  ...      0.96               30.6
# 15     7862944          112620  ...      0.97               48.4
# ..         ...             ...  ...       ...                ...
# 49    60876136          547030  ...      0.96                 81
# 69     6352117           20770  ...      1.01               92.6
# 63      299388          103000  ...      1.00               93.9
# 6     20264082         7686850  ...      0.99               86.2
# 72   127463611          377835  ...      0.94               91.8
#
# [93 rows x 25 columns]

# %%
x.shape
# Out:
# (93, 25)

# %%
y = New_world2[['Life expectancy']]
y
# Out:
#    Life expectancy
# 99            less
# 57            less
# 23            less
# 22            less
# 15            less
# ..             ...
# 49            high
# 69            high
# 63            high
# 6             high
# 72            high
#
# [93 rows x 1 columns]

# %%
y.shape
# Out:
# (93, 1)

# %%
x_train = x.iloc[:-2,:]
print(x_train.shape)
# Out:
# (91, 25)

# %%
x_test = x.iloc[-2:,:] 
x_test
# Out:
#     Population  Area (sq. mi.)  ... Sex-ratio  Urbanization rate
# 6     20264082         7686850  ...      0.99               86.2
# 72   127463611          377835  ...      0.94               91.8
#
# [2 rows x 25 columns]

# %%
y_train = y[:-2]
y_train.shape
# Out:
# (91, 1)

# %%
y_test = y[-2:]
y_test
# Out:
#    Life expectancy
# 6             high
# 72            high

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
myKNN = KNeighborsClassifier(n_neighbors=3)

# %%
myKNN.fit(x_train,y_train)
KNeighborsClassifier(n_neighbors=3, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1081-44b4b62b8069> in <module>()
# ----> 1 myKNN.fit(x_train,y_train)
#       2 KNeighborsClassifier(n_neighbors=3, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1124         """
#    1125         if not isinstance(X, (KDTree, BallTree)):
# -> 1126             X, y = check_X_y(X, y, "csr", multi_output=True)
#    1127
#    1128         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
myKNN.predict(x_test)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Nutsudapenpong/DPDM/blob/master/ppp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
base_path = '/content/drive/My Drive/TEST'

# %%
os.listdir(base_path)
# Out:
# ['Fertility_new.xlsx', 'countries_of_the_world.xlsx']

# %%
Countries_name = os.path.join(base_path, 'countries_of_the_world.xlsx')
Fertility_name = os.path.join(base_path, 'Fertility_new.xlsx')

# %%
Countries_name2 = pd.read_excel(Countries_name)

# %%
Countries_name2
# Out:
#                  Country  ... GDPpercapita
# 0            Afghanistan  ...       2182.0
# 1                Algeria  ...      16091.0
# 2                 Angola  ...       6763.0
# 3    Antigua and Barbuda  ...      30593.0
# 4              Argentina  ...      19971.0
# ..                   ...  ...          ...
# 212           West Bank   ...          NaN
# 213      Western Sahara   ...          NaN
# 214                Yemen  ...          NaN
# 215               Zambia  ...          NaN
# 216             Zimbabwe  ...          NaN
#
# [217 rows x 20 columns]

# %%
Fertility_name2 = pd.read_excel(Fertility_name)

# %%
Fertility_name2
# Out:
#                  Country  Fertility  ...  Suicide rate  Urbanization rate
# 0            Afghanistan        4.5  ...           6.4               26.0
# 1                Algeria        3.0  ...           3.3               73.7
# 2                 Angola        5.5  ...           8.9               66.8
# 3    Antigua and Barbuda        2.0  ...           0.5               24.4
# 4              Argentina        2.3  ...           9.1               92.1
# ..                   ...        ...  ...           ...                ...
# 152            Venezuela        2.3  ...           3.8               88.3
# 153              Vietnam        2.0  ...           7.0               37.3
# 154                Yemen        3.8  ...           9.8               36.6
# 155               Zambia        4.6  ...          11.3               44.6
# 156             Zimbabwe        3.6  ...          19.1               32.2
#
# [157 rows x 10 columns]

# %%
#------------------------------------------

# %%
New_table = Countries_name2.merge(Fertility_name2, on='Country')

# %%
New_table
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...              26.0
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
# 156             Zimbabwe  ...              32.2
#
# [157 rows x 29 columns]

# %%
#------------------------------------------

# %%
New_table.head()
# Out:
#                Country  ... Urbanization rate
# 0          Afghanistan  ...              26.0
# 1              Algeria  ...              73.7
# 2               Angola  ...              66.8
# 3  Antigua and Barbuda  ...              24.4
# 4            Argentina  ...              92.1
#
# [5 rows x 29 columns]

# %%
New_table.tail()
# Out:
#        Country  ... Urbanization rate
# 152  Venezuela  ...              88.3
# 153    Vietnam  ...              37.3
# 154      Yemen  ...              36.6
# 155     Zambia  ...              44.6
# 156   Zimbabwe  ...              32.2
#
# [5 rows x 29 columns]

# %%
New_table.shape
# Out:
# (157, 29)

# %%
New_table.describe()
# Out:
#          Population          Area  ...  Suicide rate  Urbanization rate
# count  1.570000e+02  1.570000e+02  ...    157.000000         157.000000
# mean   3.971542e+07  8.326234e+05  ...      9.777070          59.042675
# std    1.402978e+08  2.103617e+06  ...      5.510908          22.367459
# min    5.636100e+04  3.160000e+02  ...      0.400000          13.300000
# 25%    3.177388e+06  5.110000e+04  ...      5.900000          42.200000
# 50%    8.989046e+06  2.076000e+05  ...      9.100000          58.400000
# 75%    2.701973e+07  6.376570e+05  ...     12.900000          78.100000
# max    1.313974e+09  1.707520e+07  ...     30.200000         100.000000
#
# [8 rows x 26 columns]

# %%
#------------------------------------------

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(New_table['Country'], New_table['Life expectancy'])

# %%
plt.scatter(New_table['Country'], New_table['Suicide rate'])

# %%
ret = plt.boxplot(New_table['Life expectancy'], showmeans=True, whis=0.8, vert=False)

# %%
ret
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fefe88628d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fefe8b3bf60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fefe8743588>],
#  'means': [<matplotlib.lines.Line2D at 0x7fefe874e0f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fefe8b3b978>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fefe8862b70>,
#   <matplotlib.lines.Line2D at 0x7fefe8862978>]}

# %%
ret['fliers']

# %%
ret['fliers'][0].get_xdata()
# Out:
# array([58.9, 52.8, 54. , 58. , 53.7, 58.9, 54.3, 54.3, 56.7])

# %%
ret['whiskers'][0].get_xdata()
# Out:
# array([67.1, 60.2])

# %%
ret2 = plt.boxplot(New_table['Suicide rate'], showmeans=True, whis=0.8, vert=False)

# %%
ret2
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fefe8b1c6a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fefe8b44550>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fefe8b01668>],
#  'means': [<matplotlib.lines.Line2D at 0x7fefe8b01550>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fefe8b019e8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fefe885a668>,
#   <matplotlib.lines.Line2D at 0x7fefe8b449b0>]}

# %%
ret2['fliers'][0].get_xdata()
# Out:
# array([21.4, 19.5, 30.2, 22.8, 28.9, 25.7, 26.5, 23.2, 20. , 19.1])

# %%
ret2['whiskers'][0].get_xdata()
# Out:
# array([5.9, 0.4])

# %%
ret2['whiskers'][1].get_xdata()
# Out:
# array([12.9, 18.5])

# %%
ret2['boxes'][0].get_xdata()
# Out:
# array([ 5.9,  5.9, 12.9, 12.9,  5.9])

# %%
#------------------------------------------

# %%
New_table_nm = New_table[New_table['Life expectancy']>=ret['whiskers'][0].get_xdata()[1]]
New_table_nm = New_table_nm[(New_table_nm['Life expectancy']<=ret['whiskers'][1].get_xdata()[1])]

# %%
New_table_nm2 = New_table_nm[New_table_nm['Suicide rate']>=ret2['whiskers'][0].get_xdata()[1]]
New_table_nm2 = New_table_nm2[(New_table_nm2['Suicide rate']<=ret2['whiskers'][1].get_xdata()[1])]

# %%
import seaborn as sn
import matplotlib.pyplot as plt

df = pd.DataFrame(New_table_nm2,columns=['Population', 'Area', 'PopDensity', 'Netmigration',	'Infantmortality',	'Literacy',	'Phone',	'Arable',	'Crops',	'Other',	'Climate', 'Birthrate',	'Deathrate',	'Agriculture',	'Industry',	'Service',	'GDPpercapita_x',	'Fertility',	'GDPpercapita_y',	'Life expectancy',	'Meat consumption',	'Median age',	'Population growth',	'Sex ratio',	'Suicide rate',	'Urbanization rate'])

corrMatrix = df.corr()
sn.heatmap(corrMatrix)
plt.show()

# %%
New_table_nm2.isnull()
# Out:
#      Country  Region  Population  ...  Sex ratio  Suicide rate  Urbanization rate
# 0      False   False       False  ...      False         False              False
# 1      False   False       False  ...      False         False              False
# 2      False   False       False  ...      False         False              False
# 3      False   False       False  ...      False         False              False
# 4      False   False       False  ...      False         False              False
# ..       ...     ...         ...  ...        ...           ...                ...
# 151    False   False       False  ...      False         False              False
# 152    False   False       False  ...      False         False              False
# 153    False   False       False  ...      False         False              False
# 154    False   False       False  ...      False         False              False
# ...

# %%
New_table_nm2.isnull().any()
# Out:
# Country              False
# Region               False
# Population           False
# Area                 False
# PopDensity           False
# Coastline            False
# Netmigration         False
# Infantmortality      False
# Literacy              True
# Phone                 True
# Arable               False
# Crops                False
# Other                False
# Climate               True
# Birthrate             True
# Deathrate             True
# Agriculture           True
# Industry              True
# Service               True
# GDPpercapita_x        True
# Fertility            False
# GDPpercapita_y       False
# Life expectancy      False
# Meat consumption     False
# Median age           False
# Population growth    False
# Sex ratio            False
# Suicide rate         False
# Urbanization rate    False
# dtype: bool

# %%
New_table_nm2.isnull().any().any()
# Out:
# True

# %%
New_table_dropped_Literacy = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Literacy'].mean() 
New_table_nm2[['Literacy']] = New_table_nm2[['Literacy']].fillna(New_table_dropped_Literacy)

# %%
New_table_dropped_Phones = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Phone'].mean() 
New_table_nm2[['Phone']] = New_table_nm2[['Phone']].fillna(New_table_dropped_Phones)

# %%
New_table_dropped_Climate = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Climate'].mean() 
New_table_nm2[['Climate']] = New_table_nm2[['Climate']].fillna(New_table_dropped_Climate)

# %%
New_table_dropped_Birthrate = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Birthrate'].mean()
New_table_nm2[['Birthrate']] = New_table_nm2[['Birthrate']].fillna(New_table_dropped_Birthrate)

# %%
New_table_dropped_Deathrate = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Deathrate'].mean() 
New_table_nm2[['Deathrate']] = New_table_nm2[['Deathrate']].fillna(New_table_dropped_Deathrate)

# %%
New_table_dropped_Agriculture = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Agriculture'].mean()
New_table_nm2[['Agriculture']] = New_table_nm2[['Agriculture']].fillna(New_table_dropped_Agriculture)

# %%
New_table_dropped_Industry = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Industry'].mean() 
New_table_nm2[['Industry']] = New_table_nm2[['Industry']].fillna(New_table_dropped_Industry)

# %%
New_table_dropped_Service = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['Service'].mean() 
New_table_nm2[['Service']] = New_table_nm2[['Service']].fillna(New_table_dropped_Service)

# %%
New_table_dropped_GDP_per_capita_x = New_table_nm2.dropna(subset=['Literacy', 'Phone', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDPpercapita_x'])['GDPpercapita_x'].mean()
New_table_nm2[['GDPpercapita_x']] = New_table_nm2[['GDPpercapita_x']].fillna(New_table_dropped_GDP_per_capita_x)

# %%
New_table_nm2.isnull().any()
# Out:
# Country              False
# Region               False
# Population           False
# Area                 False
# PopDensity           False
# Coastline            False
# Netmigration         False
# Infantmortality      False
# Literacy             False
# Phone                False
# Arable               False
# Crops                False
# Other                False
# Climate              False
# Birthrate            False
# Deathrate            False
# Agriculture          False
# Industry             False
# Service              False
# GDPpercapita_x       False
# Fertility            False
# GDPpercapita_y       False
# Life expectancy      False
# Meat consumption     False
# Median age           False
# Population growth    False
# Sex ratio            False
# Suicide rate         False
# Urbanization rate    False
# dtype: bool

# %%
New_table_nm2.isnull().any().any()
# Out:
# False

# %%
#------------------------------------------

# %%
New_s = New_table_nm2[New_table_nm2['Life expectancy']< 67]
New_s['Life expectancy']
# Out:
# 0      64.5
# 2      60.8
# 15     61.5
# 22     61.2
# 23     61.2
# 33     64.1
# 39     66.6
# 45     65.9
# 47     66.2
# 50     66.2
# 53     63.8
# 57     61.2
# 60     63.7
# 75     63.3
# 83     63.7
# 87     66.7
# 88     63.8
# 93     64.7
# 99     60.2
# 100    63.4
# 105    62.0
# 112    64.3
# 129    63.9
# 132    65.1
# 137    65.0
# 139    60.8
# 154    66.1
# 155    63.5
# Name: Life expectancy, dtype: float64

# %%
New_ss = New_table_nm2.replace([New_s['Life expectancy']],'0')
New_ss
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_h = New_table_nm2[New_table_nm2['Life expectancy'] > 77]
New_h['Life expectancy']
# Out:
# 6      83.3
# 7      81.4
# 9      77.2
# 11     79.1
# 13     81.5
# 18     77.3
# 26     82.3
# 30     80.0
# 32     77.1
# 34     80.1
# 35     78.3
# 36     78.6
# 37     79.2
# 38     80.8
# 46     78.6
# 49     82.5
# 52     81.2
# 54     82.1
# 63     82.9
# 68     82.1
# 69     82.8
# 70     83.6
# 72     84.5
# 81     78.9
# 86     82.1
# 91     82.4
# 102    82.1
# 103    82.1
# 108    82.5
# 109    77.6
# 111    78.3
# 116    78.5
# 125    83.8
# 126    81.2
# 130    83.4
# 134    82.7
# 142    78.3
# 146    77.8
# 147    81.2
# 148    78.9
# 149    77.8
# Name: Life expectancy, dtype: float64

# %%
New_hh = New_table_nm2.replace([New_h['Life expectancy']],'2')
New_hh
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_m = New_table_nm2[New_table_nm2['Life expectancy'] >= 67]
New_m2 = New_m[New_m['Life expectancy'] <= 77]
New_m2['Life expectancy']
# Out:
# 1      76.7
# 3      76.9
# 4      76.5
# 5      74.9
# 8      72.9
#        ...
# 145    72.0
# 150    71.5
# 151    70.3
# 152    72.1
# 153    75.3
# Name: Life expectancy, Length: 71, dtype: float64

# %%
New_mm = New_table_nm2.replace([New_m2['Life expectancy']],'1')
New_mm
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_world = New_ss.replace([New_h['Life expectancy']],'2')
New_world
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_world2 = New_world.replace([New_m['Life expectancy']],'1')
New_world2
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_sw = New_table_nm2[New_table_nm2['Suicide rate']< 5.9]
New_sw['Suicide rate']
# Out:
# 1      3.3
# 3      0.5
# 5      5.7
# 8      2.6
# 9      5.7
# 11     0.4
# 43     4.4
# 48     5.5
# 54     3.8
# 56     1.7
# 57     2.9
# 61     3.4
# 65     3.7
# 66     4.0
# 67     4.1
# 69     5.2
# 70     5.5
# 71     2.0
# 73     3.7
# 75     5.6
# 77     2.2
# 81     3.2
# 84     5.5
# 95     5.2
# 98     3.1
# 109    3.5
# 110    3.1
# 111    4.4
# 114    5.1
# 115    3.7
# 120    3.4
# 135    2.4
# 136    3.3
# 141    3.2
# 146    2.7
# 151    5.4
# 152    3.8
# Name: Suicide rate, dtype: float64

# %%
New_ssw = New_table_nm2.replace([New_sw['Suicide rate']],'0')
New_ssw
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...              26.0
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_hw = New_table_nm2[New_table_nm2['Suicide rate'] > 12.9]
New_hw['Suicide rate']
# Out:
# 13     15.7
# 15     15.7
# 22     14.8
# 23     15.0
# 27     15.1
# 44     13.5
# 45     13.8
# 46     14.4
# 62     13.6
# 63     13.3
# 64     16.5
# 72     14.3
# 76     15.2
# 80     17.2
# 83     13.4
# 96     13.4
# 97     13.3
# 116    13.4
# 126    13.3
# 131    14.2
# 134    13.8
# 139    16.6
# 145    18.5
# 148    13.7
# 149    16.5
# Name: Suicide rate, dtype: float64

# %%
New_hhw = New_table_nm2.replace([New_hw['Suicide rate']],'2')
New_hhw
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_mw = New_table_nm2[New_table_nm2['Suicide rate'] >= 5.9]
New_m2w = New_mw[New_mw['Suicide rate'] <= 12.9]
New_m2w['Suicide rate']
# Out:
# 0       6.4
# 2       8.9
# 4       9.1
# 6      11.7
# 7      11.4
#        ...
# 147     7.6
# 150     7.4
# 153     7.0
# 154     9.8
# 155    11.3
# Name: Suicide rate, Length: 78, dtype: float64

# %%
New_mmw = New_table_nm2.replace([New_m2w['Suicide rate']],'1')
New_mmw
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...              26.0
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_worldw = New_ssw.replace([New_hw['Suicide rate']],'2')
New_worldw
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_world2w = New_worldw.replace([New_mw['Suicide rate']],'1')
New_world2w
# Out:
#                  Country  ... Urbanization rate
# 0            Afghanistan  ...                26
# 1                Algeria  ...              73.7
# 2                 Angola  ...              66.8
# 3    Antigua and Barbuda  ...              24.4
# 4              Argentina  ...              92.1
# ..                   ...  ...               ...
# 151              Vanuatu  ...              25.5
# 152            Venezuela  ...              88.3
# 153              Vietnam  ...              37.3
# 154                Yemen  ...              36.6
# 155               Zambia  ...              44.6
#
# [140 rows x 29 columns]

# %%
New_world2[New_world2['Crops']=='4..17']
# Out:
#    Country                               Region  ...  Suicide rate  Urbanization rate
# 69  Israel  NEAR EAST                            ...           5.2               92.6
#
# [1 rows x 29 columns]

# %%
New_world2['Crops']= New_world2['Crops'].replace('4..17','4.17')

# %%
#------------------------------------------

# %%
x = New_world2[['Literacy','Climate','GDPpercapita_y','Meat consumption','Median age', 'Phone']]
x
# Out:
#     Literacy   Climate  GDPpercapita_y Meat consumption  Median age  Phone
# 0         36  1.000000          2182.0             17.3        27.4    3.2
# 1         70  1.000000         16091.0             18.3        32.9   78.1
# 2         42  2.086022          6763.0               19        15.9    7.8
# 3         89  2.000000         30593.0               56        31.9  549.9
# 4       97.1  3.000000         19971.0             79.7        31.7  220.4
# ..       ...       ...             ...              ...         ...    ...
# 151       53  2.000000          3039.0             32.6        22.0   32.6
# 152     93.4  2.000000         16055.0             56.6        28.3  140.1
# 153     90.3  2.000000          8677.0             28.6        30.5  187.7
# 154     50.2  1.000000          2312.0             14.7        19.5   37.2
# 155     80.6  2.000000          4174.0             11.9        16.8    8.2
#
# [140 rows x 6 columns]

# %%
y = New_world2[['Life expectancy']]
y
# Out:
#     Life expectancy
# 0                 0
# 1                 1
# 2                 0
# 3                 1
# 4                 1
# ..              ...
# 151               1
# 152               1
# 153               1
# 154               0
# 155               0
#
# [140 rows x 1 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
print(f'{x_train.shape} {x_test.shape}')
# Out:
# (112, 6) (28, 6)

# %%
from sklearn.model_selection import cross_val_score

# %%
KNN_k3_wU = KNeighborsClassifier(n_neighbors=3) #Model1

# %%
cross_val_score(KNN_k3_wU, x_train, y_train, cv=5) 
cross_val_score(KNN_k3_wU, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wD = KNeighborsClassifier(n_neighbors=3, weights='distance') #Model2
cross_val_score(KNN_k3_wD, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wF = KNeighborsClassifier(n_neighbors=3, weights='uniform') #Model3
cross_val_score(KNN_k3_wF, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wH = KNeighborsClassifier(n_neighbors=4, weights='distance') #Model4
cross_val_score(KNN_k3_wH, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wG = KNeighborsClassifier(n_neighbors=4, weights='uniform') #Model5
cross_val_score(KNN_k3_wG, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wI = KNeighborsClassifier(n_neighbors=5, weights='distance') #Model6
cross_val_score(KNN_k3_wI, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wI = KNeighborsClassifier(n_neighbors=5, weights='distance') #The best model
KNN_k3_wI.fit(x_train,y_train)
KNN_k3_wI.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# 0.75

# %%
x = New_world2[['Climate', 'Deathrate']]
x
# Out:
#       Climate  Deathrate
# 0    1.000000      20.34
# 1    1.000000       4.61
# 2    2.086022      24.20
# 3    2.000000       5.37
# 4    3.000000       7.55
# ..        ...        ...
# 151  2.000000       7.82
# 152  2.000000       4.92
# 153  2.000000       6.22
# 154  1.000000       8.30
# 155  2.000000      19.93
#
# [140 rows x 2 columns]

# %%
z = New_world2w[['Suicide rate']]
z
# Out:
#     Suicide rate
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ..           ...
# 151            0
# 152            0
# 153            1
# 154            1
# 155            1
#
# [140 rows x 1 columns]

# %%
x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.2)

# %%
print(f'{x_train.shape} {x_test.shape}')
# Out:
# (112, 2) (28, 2)

# %%
KNN_k3_wU = KNeighborsClassifier(n_neighbors=3) #Model1
cross_val_score(KNN_k3_wU, x_train, z_train, cv=5) 
cross_val_score(KNN_k3_wU, x_train, z_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wD = KNeighborsClassifier(n_neighbors=3, weights='distance') #Model2
cross_val_score(KNN_k3_wD, x_train, z_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wF = KNeighborsClassifier(n_neighbors=3, weights='uniform') #Model3
cross_val_score(KNN_k3_wF, x_train, z_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wH = KNeighborsClassifier(n_neighbors=4, weights='distance') #Model4
cross_val_score(KNN_k3_wH, x_train, z_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wG = KNeighborsClassifier(n_neighbors=4, weights='uniform') #Model5
cross_val_score(KNN_k3_wG, x_train, z_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wI = KNeighborsClassifier(n_neighbors=5, weights='distance') #Model6
cross_val_score(KNN_k3_wI, x_train, z_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
KNN_k3_wI = KNeighborsClassifier(n_neighbors=5, weights='distance') #The best model
KNN_k3_wI.fit(x_train,y_train)
KNN_k3_wI.score(x_test,z_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# 0.2857142857142857
